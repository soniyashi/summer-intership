# %%
print("hi")
# Out:
# hi

# %%
name = "sakshi"
print(name)
type(name)
# Out:
# sakshi
# str

# %%
mob = 5555555555
type(mob)
# Out:
# int

# %%
age = 28.9
type(age)
# Out:
# float

# %%
ticket = True
type(ticket)
# Out:
# bool

# %%
a = 1
b = 2
a+b
# Out:
# 3

# %%
a-b
# Out:
# -1

# %%
b-a
# Out:
# 1

# %%
a*b
# Out:
# 2

# %%
a/b
# Out:
# 0.5

# %%
b/a
# Out:
# 2.0

# %%
name = input("enter mobile name")
# Out:
# enter mobile name sakshi

# %%
mobile = input("enter mobile number")
# Out:
# enter mobile number 555555555

# %%
type(mobile)
# Out:
# str

# %%
mobile = int(input("enter mobile number"))
# Out:
# enter mobile number 999999999

# %%
type(mobile)
# Out:
# int

# %%
#comparision operators 
"""
    line1
    line2
    (use multi line commment)"""
# Out:
# '\n    line1\n    line2\n    (use multi line commment)'

# %%
age = int(input("enter your age :"))
# Out:
# enter your age : 27

# %%
age >18
# Out:
# True

# %%
age==18
# Out:
# False

# %%
age>= 18
# Out:
# True

# %%
age<=10
# Out:
# False

# %%
#conditional sentence

# %%
age = int(input("enter your age "))
if age >= 18:
          print("person can vote")
else:
          print(" you are under age  sorry you can not vote")
# Out:
# enter your age  20
# person can vote

# %%
age = int(input("enter your age "))
ticket = True 
if age >= 18:
    if ticket == True:
        print ("person can watch movie")
    else:
        print("you are under age sorry you can not watch movie")
# Out:
# enter your age  56
# person can watch movie

# %%
age = int(input("enter your age "))
ticket = True 
if age >= 18:
    if ticket == True:
        print ("person can watch movie")
else:
        print("you are under age sorry you can not watch movie")
# Out:
# enter your age  14
# you are under age sorry you can not watch movie

# %%
print("""
1. addition
2. substraction
3. multiplication
4. division
""")

choice = int(input("enter your choice"))
if choice == 1:
             num1 = int(input("enter first number:"))
             num2 =int(input("enter second number:"))
             print("addition is:" , num1 + num2)
elif choice == 2:
                num1 = int(input("enter first number:"))
                num2 =int(input("enter second number:"))
                print("substraction is:" , num1 - num2)
elif choice == 3:
                num1 = int(input("enter first number:"))
                num2 =int(input("enter second number:"))
                print("multiplication is:" , num1 * num2) 
elif choice == 4:
                num1 = int(input("enter first number:"))
                num2 =int(input("enter second number:"))
                print("division is:" , num1 / num2)
else:
     print("enter correct choice")
# Out:
# 1. addition
# 2. substraction
# 3. multiplication
# 4. division
# enter your choice 5
# enter correct choice

# %%
while True:
    print("""
    1. addition
    2. subtraction
    3. multiplication
    4. division
    5. stop
    """)

    choice = int(input("Enter your choice: "))

    if choice == 1:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        print("Addition is:", num1 + num2)

    elif choice == 2:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        print("Subtraction is:", num1 - num2)

    elif choice == 3:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        print("Multiplication is:", num1 * num2)

    elif choice == 4:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        print("Division is:", num1 / num2)

    elif choice == 5:
        print("Calculator stopped")
        break

    else:
        print("Enter correct choice")
# Out:
#     1. addition
#     2. subtraction
#     3. multiplication
#     4. division
#     5. stop
# Enter your choice:  5
# Calculator stopped
