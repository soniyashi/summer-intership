# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("spam.csv", encoding="latin1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='str')

# %%
df = df [["v1", "v2"]]

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={"v1": "label", "v2": "message" },inplace=True)

# %%
df.head(2)
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(f"Spam Message : {(df["label"] == "spam").sum()}")
# Out:
# Spam Message : 653

# %%
print(f"HAM Message : {(df["label"] == "ham").sum()}")
# Out:
# HAM Message : 4516

# %%
print("FREE ENTry of concert ".lower())
# Out:
# free entry of concert

# %%
df["message"] = df["message"].str.lower()

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  go until jurong point, crazy.. available only ...
# 1   ham                      ok lar... joking wif u oni...
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...
# 3   ham  u dun say so early hor... u c already then say...
# 4   ham  nah i don't think he goes to usf, he lives aro...

# %%
import re

# %%
example = "Free enetry in 2 a weklk !!!! hurrah you won fa tesxt 737377373"

# %%
example_clean = re.sub(r"[^a-z \s]", "" , example)

# %%
print(example_clean)
# Out:
# ree enetry in  a weklk  hurrah you won fa tesxt

# %%
df['message'] = df['message'].apply( lambda x: re.sub(r'[^a-z\s]','',x))

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  go until jurong point crazy available only in ...
# 1   ham                            ok lar joking wif u oni
# 2  spam  free entry in  a wkly comp to win fa cup final...
# 3   ham        u dun say so early hor u c already then say
# 4   ham  nah i dont think he goes to usf he lives aroun...

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download("punkt")

# %%
nltk.download("stopwords")

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user'\AppData\Roaming\nltk_data...
# True

# %%
from nltk.tokenize import word_tokenize

# %%
sample = "hellp alll how are you doing today "

# %%
sample_token = word_tokenize(sample)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sample_token = word_tokenize(sample)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# ...

# %%
print(sample_token)

# %%
from nltk.corpus import stopwords

# %%
df['message'] = df['message'].apply( lambda x : " ".join (
    [words for words in word_tokenize(x) 
     if words not in stopwords]
))

# %%
print (df["message"][10])

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
df["message"] = df["message"].apply(
    lambda x : " ".join ([stemmer.stem(word) for word in x.split() ]) 
)

# %%
from sklearn.feature_extraction.text import  TfidfVectorizer

# %%
X = df["message"]

# %%
Y = df["label"]

# %%
tfidf = TfidfVectorizer(max_features=3000)

# %%
X_vec = tfidf.fit_transform(X)

# %%
X_vec.shape[1]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()

# %%
model.fit(X_train, Y_train)

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix ,classification_report

# %%
accuracy_score = accuracy_score(Y_test, Y_pred)

# %%
print(accuracy_score)

# %%
cm = confusion_matrix(Y_test,Y_pred)

# %%
cm

# %%
def precit_message (message ):
    msg = message.lower()
    msg = re.sub((r'[^a-z\s]'), "",msg)
    token = word_tokenize(msg)
    token= [w for w in token 
           if w not in stopwords]
    tokens= [stemmer.stem(w) for w in token]
    clean_msg = " ".join(tokens)
    vec = tfidf.transform([clean_msg])
    result = model.predict(vec)[0]
    prob = model.predict(vec)[0]
    return result, prob

# %%
text_msg = """Congratulation you won a lotterly of 100000 rs click on thhe clink to claim your winning price .
    other wise it will be given to others . 

    URgent click the link to claim your Money 
    """

# %%
precit_message(text_msg)
