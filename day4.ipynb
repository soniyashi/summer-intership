# %%
# !pip install pyttsx3

# %%
import pyttsx3

engine = pyttsx3.init()

speak = input("Enter what you want to speak: ")

engine.say(speak)

engine.runAndWait()
# Out:
# Enter what you want to speak:  hii yashi

# %%
# !pip install SpeechRecognition

# %%
import speech_recognition as sr

r = sr.Recognizer()

with sr.Microphone() as source:
    print("Speak something...")
    audio = r.listen(source)

    text = r.recognize_google(audio)
    print("You said:", text)
# Out:
# Speak something...
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Cell In[5], line 9
#       6 print("Speak something...")
#       7 audio = r.listen(source)
# ----> 9 text = r.recognize_google(audio)
#      10 print("You said:", text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\speech_recognition\recognizers\google.py:263, in recognize_legacy(recognizer, audio_data, key, language, pfilter, show_all, with_confidence, endpoint)
#     256 response_text = obtain_transcription(
#     257     request, timeout=recognizer.operation_timeout
#     258 )
#     260 output_parser = OutputParser(
#     261     show_all=show_all, with_confidence=with_confidence
#     262 )
# --> 263 return output_parser.parse(response_text)
#
# ...

# %%
# !pip install pywhatkit

# %%
import pywhatkit

search = input("What do you want to search? ")

pywhatkit.search(search)
# Out:
# What do you want to search?  google

# %%
search = input("enter video name")
pywhatkit.playonyt(search)
# Out:
# enter video name comedy
# 'https://www.youtube.com/watch?v=LBfajqsq6_c\\\\u0026pp=ygUGY29tZWR5'

# %%
import pywhatkit

text = "Python is easy"

pywhatkit.text_to_handwriting(text, "handwriting.png")
print ("notes created")
# Out:
# ---------------------------------------------------------------------------
# UnableToAccessApi                         Traceback (most recent call last)
# Cell In[35], line 5
#       1 import pywhatkit
#       3 text = "Python is easy"
# ----> 5 pywhatkit.text_to_handwriting(text, "handwriting.png")
#       6 print ("notes created")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pywhatkit\handwriting.py:22, in text_to_handwriting(string, save_to, rgb)
#      20         file.close()
#      21 elif 400 <= status_code <= 599:
# ---> 22     raise exceptions.UnableToAccessApi("Unable to access Pywhatkit api right now")
#
# UnableToAccessApi: Unable to access Pywhatkit api right now

# %%
# !pip install pillow

# %%
from PIL import Image, ImageDraw

text = "Python is easy"

img = Image.new("RGB", (500, 200), color=(255,255,255))

draw = ImageDraw.Draw(img)

draw.text((50, 80), text, fill="black")

img.save("handwriting.png")

print("notes created!")
# Out:
# notes created!

# %%
# !pip install pyjokes

# %%
import pyjokes
joke = pyjokes.get_joke()
print(joke)
# Out:
# When Apple employees die, does their life HTML5 in front of their eyes?

# %%
# !pip install qrcode

# %%
import qrcode
img = qrcode.make("url")
img.save("google_search.phg")

# %%
import random 
chrs = "abcdefg1234567890ABCDEFG"
password = ""
ran = range(0,8)
print(ran)
# Out:
# range(0, 8)

# %%
ran = range(0,8)
print(ran)
# Out:
# range(0, 8)

# %%
for i in range(1, 8):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(1,8,2):
    print("*")
# Out:
# *
# *
# *
# *

# %%
for i in range(1,8,2):
    print(i*"*")
    i+1
# Out:
# *
# ***
# *****
# *******

# %%
for i in range(8):
    password += random.choice(chrs)
    print("password" , password)
# Out:
# password 7
# password 7b
# password 7bE
# password 7bE3
# password 7bE3c
# password 7bE3cA
# password 7bE3cAc
# password 7bE3cAc6
