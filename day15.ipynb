# %%
#multi linear regression

# %%
import pandas as pd

# %%
df = pd.read_csv('Student_Performance.csv')

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(127)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores  Sleep Hours  \
# count    9873.000000      9873.000000  9873.000000
# mean        4.992100        69.441102     6.531652
# std         2.589081        17.325601     1.697683
# min         1.000000        40.000000     4.000000
# 25%         3.000000        54.000000     5.000000
# 50%         5.000000        69.000000     7.000000
# 75%         7.000000        85.000000     8.000000
# max         9.000000        99.000000     9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                       9873.000000        9873.000000
# mean                           4.583004          55.216651
# std                            2.867202          19.208570
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          70.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.scatter(df["Hours Studied"] , df["Performance Index"])
plt.xlabel("Hours Studied")
plt.ylabel("Performance Index")
plt.title("Hours Studied vs Performance Index")
plt.show()

# %%
plt.figure()
plt.scatter(df["Hours Studied"] , df["Sample Question Papers Practiced"])
plt.xlabel("Hours Studied")
plt.ylabel("Sample Question Papers Practiced")
plt.title("Hours Studied vs Sample Question Papers Practiced")
plt.show()

# %%
plt.figure()
plt.scatter(df["Hours Studied"] , df["Sleep Hours"])
plt.xlabel("Hours Studied")
plt.ylabel("Sleep Hours")
plt.title("Hours Studied vs Sleep Hours")
plt.show()

# %%
plt.figure()
plt.scatter(df["Hours Studied"] , df["Previous Scores"])
plt.xlabel("Hours Studied")
plt.ylabel("Previous Scores")
plt.title("Hours Studied vs Previous Scores")
plt.show()

# %%
plt.figure()
plt.scatter(df["Previous Scores"] , df["Performance Index"])
plt.xlabel("Previous Scores")
plt.ylabel("Performance Index")
plt.title("Previous Scores vs Performance Index")
plt.show()

# %%
plt.figure()
plt.scatter(df["Sleep Hours"] , df["Performance Index"])
plt.xlabel("Sleep Hours")
plt.ylabel("Performance Index")
plt.title("Sleep Hours vs Performance Index")
plt.show()

# %%
plt.figure()
plt.scatter(df["Sample Question Papers Practiced"] , df["Performance Index"])
plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Performance Index")
plt.title("Sample Question Papers Practiced vs Performance Index")
plt.show()

# %%
plt.figure()
plt.scatter(df["Previous Scores"] , df["Sleep Hours"])
plt.xlabel("Previous Scores")
plt.ylabel("Sleep Hours")
plt.title("Previous Scores vs Sleep Hours")
plt.show()

# %%
plt.figure()
plt.scatter(df["Previous Scores"] , df["Sample Question Papers Practiced"])
plt.xlabel("Previous Scores")
plt.ylabel("Sample Question Papers Practiced")
plt.title("Previous Scores vs Sample Question Papers Practiced")
plt.show()

# %%
plt.figure()
plt.scatter(df["Sleep Hours"] , df["Sample Question Papers Practiced"])
plt.xlabel("Sleep Hours")
plt.ylabel("Sample Question Papers Practiced")
plt.title("Sleep Hours vs Sample Question Papers Practiced")
plt.show()

# %%
df["Extracurricular Activities"].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
df["Extracurricular Activities"] = df["Extracurricular Activities"].map({
    "Yes" : 1,
    "No" : 0
})

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
Y = df["Performance Index"]

# %%
Y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 9873, dtype: float64

# %%
X = df.drop("Performance Index" , axis=1)

# %%
X.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
#train test split method

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(
    X,
    Y,
    test_size = 0.2,
    random_state = 40
)

# %%
X_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 1546              5               89                           0            7
# 4085              3               54                           0            5
# 8283              8               48                           0            6
# 7900              7               43                           0            9
# 7201              3               44                           0            6
# ...             ...              ...                         ...          ...
# 7916              8               91                           1            4
# 3619              6               90                           0            4
# 5998              6               89                           1            4
# 5460              7               79                           0            7
# 7681              9               60                           0            4
#
# ...

# %%
X_test
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 3829              9               67                           1            5
# 4997              3               67                           1            6
# 8596              7               73                           1            5
# 747               7               53                           0            9
# 4120              2               75                           0            4
# ...             ...              ...                         ...          ...
# 7694              4               82                           1            6
# 4759              5               53                           0            4
# 5835              1               42                           1            9
# 5474              9               78                           0            4
# 8654              6               60                           1            9
#
# ...

# %%
Y_train
# Out:
# 1546    76.0
# 4085    32.0
# 8283    39.0
# 7900    32.0
# 7201    19.0
#         ...
# 7916    86.0
# 3619    77.0
# 5998    80.0
# 5460    72.0
# 7681    55.0
# Name: Performance Index, Length: 7898, dtype: float64

# %% [raw]
# Y_test

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)

# %%
comparison = pd.DataFrame({
    "Actual" : Y_test,
    "predicted" : Y_predict
})

# %%
comparison
# Out:
#       Actual  predicted
# 3829    64.0  64.233813
# 4997    48.0  46.228096
# 8596    64.0  65.024331
# 747     41.0  44.410141
# 4120    51.0  51.699180
# ...      ...        ...
# 7694    65.0  65.137028
# 4759    36.0  36.884234
# 5835    18.0  18.242521
# 5474    72.0  74.541876
# 8654    48.0  50.266059
#
# [1975 rows x 2 columns]

# %%
import joblib  #use for save model

# %%
joblib.dump(model , "Student_Performance.pkl")
# Out:
# ['Student_Performance.pkl']

# %%
joblib.load("Student_Performance.pkl")
# Out:
# LinearRegression()

# %%
load_model = joblib.load("Student_Performance.pkl")
