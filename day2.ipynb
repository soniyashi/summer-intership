# %%
mylist = ["apple" ,
          "mango" , 
          "buleberry",
          "apple"]

# %%
mylist.append("cheery")

# %%
print(mylist)
# Out:
# ['apple', 'mango', 'buleberry', 'apple', 'cheery', 'cheery', 'cheery']

# %%
mylist[0]
# Out:
# 'apple'

# %%
mylsit[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 mylsit[4]
#
# NameError: name 'mylsit' is not defined

# %%
mylist[3]
# Out:
# 'apple'

# %%
mylist.count("cheery")
# Out:
# 3

# %%
mylist.pop(3)      #remove indexing value
# Out:
# 'apple'

# %%
mylist.sort()    #alphabetically

# %%
print(mylist)
# Out:
# ['apple', 'buleberry', 'cheery', 'cheery', 'cheery', 'mango']

# %%
mylist.reverse()

# %%
print(mylist)
# Out:
# ['mango', 'cheery', 'cheery', 'cheery', 'buleberry', 'apple']

# %%
for i in mylist:
    print(i)
# Out:
# mango
# cheery
# cheery
# cheery
# buleberry
# apple

# %%
mylist.append(2222)

# %%
print(mylist)
# Out:
# ['mango', 'cheery', 'cheery', 'cheery', 'buleberry', 'apple', 2222]

# %%
mylist.append(3.14)

# %%
print(mylist)
# Out:
# ['mango', 'cheery', 'cheery', 'cheery', 'buleberry', 'apple', 2222, 3.14]

# %%
mylist.append(True)

# %%
print(mylist)
# Out:
# ['mango', 'cheery', 'cheery', 'cheery', 'buleberry', 'apple', 2222, 3.14, True]

# %%
for i in mylist:
    print(i)
# Out:
# mango
# cheery
# cheery
# cheery
# buleberry
# apple
# 2222
# 3.14
# True

# %%
for i in mylist:
    a = "apple"
    a == i
    mylist.index(i)

# %%
print(mylist.index(i))
# Out:
# 8

# %%
mylist.index("apple")
# Out:
# 5

# %%
mylist = ["apple" , "mango" , "buleberry" , "apple"]

# %%
search = input("Enter what you want to search in list: ")

for i in mylist:
    if i == search:
        print("Found at index:", mylist.index(i))
        break
else:
    print("Not found in list")
# Out:
# Enter what you want to search in list:  banana
# Not found in list

# %%
mylist  = [ "apple" , "mango", "buleberry" , "mango" , "apple"]

# %%
search = input("Enter item: ")

print("Frequency =", mylist.count(search))
# Out:
# Enter item:  apple
# Frequency = 2

# %%
#tuple

# %%
mytuple = ("tom", "jack", "bob")

# %%
type(mytuple)
# Out:
# tuple

# %%
mytuple.count("tom")
# Out:
# 1

# %%
mytuple.index("tom")
# Out:
# 0

# %%
mydict = {
    "name" : "tom",
     "mob" :  22222,
      "mail id " : "tom@india.com",
}

# %%
mydict.keys()
# Out:
# dict_keys(['name', 'mob', 'mail id '])

# %%
mydict.values()
# Out:
# dict_values(['tom', 22222, 'tom@india.com'])

# %%
mydict["name"]
# Out:
# 'tom'

# %%
mydict = {
    "name" : ["tom" , "jack"],
    "mob" : 2222,
    "mail id " :"tom@india.com",
}

# %%
mydict["name"]
# Out:
# ['tom', 'jack']

# %%
mylist = ["apple" , "mango" , "buleberry" , "apple"]

# %%
mydict = {
    "name" : mylist,
    "mob" : 22222,
    "mail id" :"tom@india.com",
}

# %%
mydict ["name"]
# Out:
# ['apple', 'mango', 'buleberry', 'apple']

# %%
myset = {"tom" , 2,3,5,6, "tom"}

# %%
myset
# Out:
# {2, 3, 5, 6, 'tom'}

# %%
import random

print("""
Welcome to Number Guessing Game

Computer vs Human

Correct choice = 2x money
""")

human_choice = int(input("Enter any number from 1 to 10: "))

computer_choice = random.randint(1, 10)

print("Computer's choice:", computer_choice)

if human_choice == computer_choice:
    print("Congratulations! You won!!!")
else:
    print("Better luck next time")
# Out:
# Welcome to Number Guessing Game
#
# Computer vs Human
#
# Correct choice = 2x money
# Enter any number from 1 to 10:  7
# Computer's choice: 4
# Better luck next time
