# %%
studnet_name1 = "sakshi"

# %%
student_NAME = "soni"

# %%
name = "Rahul"

# %%
age = 20

# %%
print(name)
# Out:
# Rahul

# %%
print(age)
# Out:
# 20

# %%
name = "doremon"

# %%
age = 18

# %%
class student:
    pass

# %%
s1 = student()

# %%
print(s1)

# %%
s2 = student()

# %%
print(s2)

# %%
print(type(s1))
# Out:
# <class '__main__.student'>

# %%
s1.name = "shinchan"

# %%
s1.age = 20

# %%
print(s1.name)
# Out:
# shinchan

# %%
print(s1.age)
# Out:
# 20

# %%
pop = student()

# %%
pop.name = "oggy"

# %%
pop.age = 22

# %%
print(pop.name)
# Out:
# oggy

# %%
print(pop.__dict__)
# Out:
# {'name': 'oggy', 'age': 22}

# %%
class visitorform:
    pass

# %%
student1= visitorform()

# %%
student2 = visitorform()

# %%
student3= visitorform()

# %%
student1.name = "Amrit"

# %%
student2.name = "yash"
student3.name = "harsh"

# %%
student1.age = 19
student2.age =20
student3.age = 18

# %%
print (student1.__dict__)
# Out:
# {'name': 'Amrit', 'age': 19}

# %%
print (student2.__dict__)
# Out:
# {'name': 'yash', 'age': 20}

# %%
print (student3.__dict__)
# Out:
# {'name': 'harsh', 'age': 18}

# %%
class Employee:
    pass

# %%
e1 = Employee()

# %%
e2 = Employee()

# %%
e1.name = "Raj"
e1.salry = 10000
e1.department = "IT"

# %%
e2.name = "Raja"
e2.salry = 100000
e2.department = "IT"

# %%
print(e1.__dict__)
# Out:
# {'name': 'Raj', 'salry': 10000, 'department': 'IT'}

# %%
print(e2.__dict__)
# Out:
# {'name': 'Raja', 'salry': 100000, 'department': 'IT'}

# %%
class student :
    def welcome (self):
        print("WELCOME TO LW")
        print("Which cource do u want ")
    def fill(self):
        print("Fill the form")

# %%
s1 = student()

# %%
s1.welcome()
# Out:
# WELCOME TO LW
# Which cource do u want

# %%
s1.fill()
# Out:
# Fill the form

# %%
class student :
    def show(self):
        print("Name : Rahul")
        print("age : 20 ")

# %%
s2 = student()

# %%
s2.show()
# Out:
# Name : Rahul
# age : 20

# %%
class student :
    def details(self):
        self.name =  "Rahul"
        self.age = 23
        print(self.name)
        print(self.age)

# %%
s3 = student()

# %%
s3.details()
# Out:
# Rahul
# 23

# %%
print(s3.__dict__)
# Out:
# {'name': 'Rahul', 'age': 23}

# %%
class student :
    def add_data(self):
        self.name =  "Rahul"
        self.age = 23
        self.city = "Jaipur"
        self.course = "DevOps"

# %%
tom = student()

# %%
tom.add_data()

# %%
print(tom.__dict__)
# Out:
# {'name': 'Rahul', 'age': 23, 'city': 'Jaipur', 'course': 'DevOps'}

# %%
class student :
    def add_data(self, name ,age  ):
        self.name =  name
        self.age = age

# %%
s1 =student()

# %%
s1.add_data( "Rahul" , 22)

# %%
print(s1.__dict__)
# Out:
# {'name': 'Rahul', 'age': 22}

# %%
harry = student()

# %%
harry.add_data("harry", 23)

# %%
print(harry.__dict__)
# Out:
# {'name': 'harry', 'age': 23}

# %%
class student:
    def add_data (self , name , age , course):
        self.name = name
        self.age = age
        self.course = course
    def display (self ):
        print("Name ", self.name)
        print("Age", self.age)
        print("course", self.course)

# %%
s1 = student()

# %%
s1.add_data("Neha" , 18 , "Python")

# %%
s1.display()
# Out:
# Name  Neha
# Age 18
# course Python

# %%
class voting:
    def add_data (self , name , age):
        self.name = name
        self.age = age
    def voting(self):
        if self.age >= 18:
            print(self.name ,"can vote")
        else:
            print(self.name , "can not vote")

# %%
rahul = voting()

# %%
rahul.add_data("Rahul",17)

# %%
rahul.voting()
# Out:
# Rahul can not vote

# %%
class result:
    def add_data(self, name , marks):
        self.name = name
        self.marks = marks
    def result(self):
        if self.marks >= 40:
            print(self.name , "pass")
        else:
            print(self.name , "fail")

# %%
s1 = result()

# %%
s1.add_data("ram" , 22)

# %%
s1.result()
# Out:
# ram fail

# %%
class Student:
    def __init__(self):
        print("Object created")

s1 = Student()
# Out:
# Object created

# %%
class student:
    def __init__(self):
        self.name = "Rahul"
        self.age = 20

s1 = student()

# %%
(s1.__dict__)
# Out:
# {'name': 'Rahul', 'age': 20}

# %%
class student:
    def __init__(self , name , age):
        self name = name
        self age = age

# %%
class bankaccount():
    def __init__(self , name , balance):
        self.name = name
        self.balance = balance
    def show (self):
        print("name:" , self.name)
        print("balance:" , self.balance)

# %%
a1 = bankaccount("A1" , 3000000)

# %%
a1.show()
# Out:
# name: A1
# balance: 3000000

# %%
class bankaccount():
    def __init__(self , name , balance):
        self.name = name
        self.balance = balance
    def deposit(self , amount):
        self.balance = self.balance + amount
    def show (self):
        print("name:" , self.name)
        print("balance:" , self.balance)

# %%
rahul = bankaccount("Rahul" , 1000000)

# %%
rahul.show()
# Out:
# name: Rahul
# balance: 1000000

# %%
rahul.deposit(1000000)

# %%
rahul.show()
# Out:
# name: Rahul
# balance: 2000000

# %%
class bankaccount():
    def __init__(self , name , balance):
        self.name = name
        self.balance = balance
    def withdraw(self , amount):
        self.balance = self.balance - amount
    def show (self):
        print("name:" , self.name)
        print("balance:" , self.balance)

# %%
rahul = bankaccount("Rahul" , 5000)

# %%
rahul.show()
# Out:
# name: Rahul
# balance: 5000

# %%
rahul.withdraw(500)

# %%
rahul.show
# Out:
# <bound method bankaccount.show of <__main__.bankaccount object at 0x00000250DEB9E5D0>>

# %%
class BankAccount:
    def __init__(self, account_holder, account_number, balance=0):
        self.account_holder = account_holder
        self.account_number = account_number
        self.balance = balance
    def deposit(self):
        amount = float(input("Enter amount to deposit: "))
        if amount > 0:
            self.balance += amount
            print("deposited successfully!")
        else:
            print("Invalid amount")
    def withdraw(self):
        amount = float(input("Enter amount to withdraw:"))
        if amount <= 0:
            print("Invalid amount")
        elif amount > self.balance:
            print("Insufficient balance")
        else:
            self.balance -= amount
            print("withdrawn successfully!")
    def check_balance(self):
        print("Current Balance: self.balance")
    def account_details(self):
        print("------ ACCOUNT DETAILS ------")
        print("Account Holder :", self.account_holder)
        print("Account Number :", self.account_number)
        print("Balance        :", self.balance)
# Create Object
customer = BankAccount(
    "sakshi",
    "1001",
    100000
)

# Function Calls
customer.account_details()
customer.deposit()
customer.withdraw()
customer.check_balance()

# Print Object Data
print(customer.__dict__)
# Out:
# ------ ACCOUNT DETAILS ------
# Account Holder : sakshi
# Account Number : 1001
# Balance        : 100000
# Enter amount to deposit:  5000
# deposited successfully!
# Enter amount to withdraw: 2000
# withdrawn successfully!
# Current Balance: self.balance
# {'account_holder': 'sakshi', 'account_number': '1001', 'balance': 103000.0}
